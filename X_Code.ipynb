# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
import pmdarima as pm
from numpy.random import seed
from scipy import stats
import statsmodels.api as sm

# %%
# X-Men

# %%
Y = pd.read_csv("X_Final.csv")
Y = Y[['Date', 'Units_Sold', 'Movie_Playing']]
Y.head()
# Out:
#       Date  Units_Sold  Movie_Playing
# 0  1997-04      179378              0
# 1  1997-04      177828              0
# 2  1997-05      162890              0
# 3  1997-05      160365              0
# 4  1997-06      173453              0

# %%
Y['Date'] = pd.to_datetime(Y['Date'])

# %%
Y.dtypes
# Out:
# Date             datetime64[ns]
# Units_Sold                int64
# Movie_Playing             int64
# dtype: object

# %%
Y.set_index('Date', inplace=True)
Y.head()
# Out:
#             Units_Sold  Movie_Playing
# Date
# 1997-04-01      179378              0
# 1997-04-01      177828              0
# 1997-05-01      162890              0
# 1997-05-01      160365              0
# 1997-06-01      173453              0

# %%
Y.index
# Out:
# DatetimeIndex(['1997-04-01', '1997-04-01', '1997-05-01', '1997-05-01',
#                '1997-06-01', '1997-06-01', '1997-07-01', '1997-07-01',
#                '1997-08-01', '1997-08-01',
#                ...
#                '2019-04-01', '2019-05-01', '2019-05-01', '2019-06-01',
#                '2019-06-01', '2019-07-01', '2019-07-01', '2019-10-01',
#                '2019-11-01', '2019-12-01'],
#               dtype='datetime64[ns]', name='Date', length=944, freq=None)

# %%
X = Y.resample('M').mean()
X.head()
# Out:
#             Units_Sold  Movie_Playing
# Date
# 1997-04-30    178603.0            0.0
# 1997-05-31    161627.5            0.0
# 1997-06-30    171565.0            0.0
# 1997-07-31    164141.5            0.0
# 1997-08-31    161535.5            0.0

# %%
X.isnull().values.any()
# Out:
# True

# %%
X.isnull().sum().sum()
# Out:
# 12

# %%
is_NaN = X.isnull()
row_has_NaN = is_NaN.any(axis=1)
rows_with_NaN = X[row_has_NaN]
print(rows_with_NaN)
# Out:
#             Units_Sold  Movie_Playing
# Date
# 1998-08-31         NaN            NaN
# 2015-08-31         NaN            NaN
# 2015-09-30         NaN            NaN
# 2015-10-31         NaN            NaN
# 2019-08-31         NaN            NaN
# 2019-09-30         NaN            NaN

# %%
X = X.fillna(method='ffill')

# %%
X.isnull().values.any()
# Out:
# False

# %%
#Statistics

# %%
np.random.seed(47)
N_rep = 10000
#Create function to run bootstrap sampling from
def bootstrap(data, func, N_rep):
    #Create empty array 
    bootstrap_rep = np.empty(N_rep)
    #Run bootstrap replicates
    for i in range(N_rep):
        bootstrap_sample = np.random.choice(data, len(data))
        bootstrap_rep[i] = func(bootstrap_sample)
    return bootstrap_rep

# %%
#Assign movie and no-movie array
movie = np.array(X[X['Movie_Playing']==1].Units_Sold)
no_movie = np.array(X[X['Movie_Playing']==0].Units_Sold)
#Find difference in mean between them
difference_mean = np.mean(movie) - np.mean(no_movie)
difference_mean
# Out:
# -21687.2711748878

# %%
#Difference of 10000 replicates
bootstrap_mean = bootstrap(movie, np.mean, N_rep) - bootstrap(no_movie, np.mean, N_rep)
#95% confidence interval
conf_interval = np.percentile(bootstrap_mean,[2.5, 97.5])
conf_interval
# Out:
# array([-29442.76034192, -13588.12274164])

# %%
#Plot histogram of values and mark the locations of the percentiles
plt.hist(bootstrap_mean, bins=50, density=True)
plt.axvline(conf_interval[0], color='red')
plt.axvline(conf_interval[1], color='red')
plt.title("X-Men")
plt.xlabel('difference in mean between the two groups')
plt.ylabel('probability')
plt.savefig('X_Stat.png', dpi=300, bbox_inches='tight')
plt.show()

# %%
# P Value

# %%
stats.ttest_ind(movie, no_movie, equal_var = False)
# Out:
# Ttest_indResult(statistic=-5.337322104414128, pvalue=4.287955543702021e-07)

# %%
# Linear Regression

# %%
#Without Movie_Playing External Predictor

# %%
plt.title("X-Men")
sns.lineplot(x=X.index, y=X.Units_Sold, data=X)
plt.savefig('X_Line.png', dpi=300, bbox_inches='tight')

# %%
train = X.loc['1997-04-30':'2015-01-31']
test= X.loc['2015-02-28':]

# %%
train.head()
# Out:
#             Units_Sold  Movie_Playing
# Date
# 1997-04-30    178603.0            0.0
# 1997-05-31    161627.5            0.0
# 1997-06-30    171565.0            0.0
# 1997-07-31    164141.5            0.0
# 1997-08-31    161535.5            0.0

# %%
test.head()
# Out:
#             Units_Sold  Movie_Playing
# Date
# 2015-02-28    42084.20            0.0
# 2015-03-31    42840.60            0.0
# 2015-04-30    38636.75            0.0
# 2015-05-31    45267.00            0.0
# 2015-06-30    48937.00            0.0

# %%
test_no_movie = X[['Units_Sold']]
test_no_movie = test_no_movie.loc['2015-02-28':]
train_no_movie = X[['Units_Sold']]
train_no_movie = train_no_movie.loc['1997-04-30':'2015-01-31']

# %%
train.shape
# Out:
# (214, 2)

# %%
test.shape
# Out:
# (59, 2)

# %%
#Find p, d, and q values to build ARIMA model
#P is the order of the Auto Regressive (AR) term or the number of lags of Y to be used as predictors
#D is the number of differencing required to make the time series stationary
#Q is the order of the Moving Average (MA) term or the number of lagged forecast errors that should go into the ARIMA model

# %%
#ARIMA

# %%
#Auto ARIMA Forecast to choose best p,d,q
model_train_arima = pm.auto_arima(train[['Units_Sold']], start_p=1, start_q=1,
                      test='adf',       # use adftest to find optimal 'd'
                      max_p=3, max_q=3, # maximum p and q
                      m=1,              # frequency of series
                      d=None,           # let model determine 'd'
                      seasonal=False,   # Seasonality
                      start_P=0, 
                      D=1, 
                      trace=True,
                      error_action='ignore',  
                      suppress_warnings=True,
                      stepwise=True)

print(model_train_arima.summary())
# Out:
# Performing stepwise search to minimize aic
# Fit ARIMA(1,0,1)x(0,0,0,0) [intercept=True]; AIC=4507.504, BIC=4520.968, Time=0.059 seconds
# Fit ARIMA(0,0,0)x(0,0,0,0) [intercept=True]; AIC=5054.279, BIC=5061.011, Time=0.010 seconds
# Fit ARIMA(1,0,0)x(0,0,0,0) [intercept=True]; AIC=4540.360, BIC=4550.458, Time=0.030 seconds
# Fit ARIMA(0,0,1)x(0,0,0,0) [intercept=True]; AIC=4914.502, BIC=4924.600, Time=0.039 seconds
# Fit ARIMA(0,0,0)x(0,0,0,0) [intercept=False]; AIC=5508.498, BIC=5511.864, Time=0.008 seconds
# Fit ARIMA(2,0,1)x(0,0,0,0) [intercept=True]; AIC=4508.045, BIC=4524.875, Time=0.102 seconds
# Fit ARIMA(1,0,2)x(0,0,0,0) [intercept=True]; AIC=4508.471, BIC=4525.301, Time=0.096 seconds
# Fit ARIMA(0,0,2)x(0,0,0,0) [intercept=True]; AIC=4867.486, BIC=4880.950, Time=0.061 seconds
# Fit ARIMA(2,0,0)x(0,0,0,0) [intercept=True]; AIC=4512.326, BIC=4525.790, Time=0.061 seconds
# Fit ARIMA(2,0,2)x(0,0,0,0) [intercept=True]; AIC=4504.165, BIC=4524.361, Time=0.200 seconds
# Fit ARIMA(3,0,2)x(0,0,0,0) [intercept=True]; AIC=4502.009, BIC=4525.571, Time=0.186 seconds
# Fit ARIMA(3,0,1)x(0,0,0,0) [intercept=True]; AIC=4500.303, BIC=4520.499, Time=0.126 seconds
# Fit ARIMA(3,0,0)x(0,0,0,0) [intercept=True]; AIC=4499.745, BIC=4516.574, Time=0.086 seconds
# Total fit time: 1.089 seconds
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:                  214
# Model:               SARIMAX(3, 0, 0)   Log Likelihood               -2244.872
# Date:                Thu, 06 Aug 2020   AIC                           4499.745
# Time:                        21:56:06   BIC                           4516.574
# Sample:                             0   HQIC                          4506.545
#                                 - 214
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# intercept   2491.3308   1417.060      1.758      0.079    -286.056    5268.717
# ar.L1          0.5201      0.052      9.972      0.000       0.418       0.622
# ar.L2          0.1991      0.060      3.292      0.001       0.081       0.318
# ar.L3          0.2569      0.058      4.440      0.000       0.143       0.370
# sigma2      7.026e+07      0.141      5e+08      0.000    7.03e+07    7.03e+07
# ===================================================================================
# Ljung-Box (Q):                       31.89   Jarque-Bera (JB):               173.65
# Prob(Q):                              0.82   Prob(JB):                         0.00
# Heteroskedasticity (H):               1.02   Skew:                             1.29
# Prob(H) (two-sided):                  0.93   Kurtosis:                         6.58
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# [2] Covariance matrix is singular or near-singular, with condition number 2.91e+23. Standard errors may be unstable.

# %%
model_train_arima.plot_diagnostics(figsize=(16,10))
plt.suptitle("X-Men ARIMA Diagnostics")
plt.savefig('X_Diag_ARIMA.png', dpi=300, bbox_inches='tight')
plt.show()

# %%
# Forecast
n_periods_arima = 59
fc_arima, confint_arima = model_train_arima.predict(n_periods=n_periods_arima, return_conf_int=True)
index_of_fc_arima = pd.date_range(train.index[-1], periods = n_periods_arima, freq='MS')

# make series for plotting purpose
fc_series_arima = pd.Series(fc_arima, index=index_of_fc_arima)
lower_series_arima = pd.Series(confint_arima[:, 0], index=index_of_fc_arima)
upper_series_arima = pd.Series(confint_arima[:, 1], index=index_of_fc_arima)

# Plot
plt.figure(figsize=(16,10))
plt.plot(test_no_movie, label='actual')
plt.plot(train_no_movie, label='training')
plt.plot(fc_series_arima, label='forecast')
plt.fill_between(lower_series_arima.index, lower_series_arima, upper_series_arima, color='k', alpha=.15)
plt.title("X-Men ARIMA Predicted vs Observed")
plt.legend(loc='upper left', fontsize=8)
plt.savefig('X_Predict_ARIMA.png', dpi=300, bbox_inches='tight')
plt.show()

# %%
def mean_absolute_percentage_error(y_true, y_pred): 
    y_true, y_pred = np.array(y_true), np.array(y_pred)
    return np.mean(np.abs((y_true - y_pred) / y_true)) * 100

# %%
mean_absolute_percentage_error(test_no_movie, fc_series_arima)
# Out:
# 43.22204140161588

# %%
#SARIMA

# %%
#Auto SARIMA Forecast to choose best p,d,q
model_train_sarima = pm.auto_arima(train[['Units_Sold']], start_p=1, start_q=1,
                      test='adf',       # use adftest to find optimal 'd'
                      max_p=3, max_q=3, # maximum p and q
                      m=12,              # frequency of series
                      d=None,           # let model determine 'd'
                      seasonal=True,   # Seasonality
                      start_P=0, 
                      D=1, 
                      trace=True,
                      error_action='ignore',  
                      suppress_warnings=True,
                      stepwise=True)

print(model_train_sarima.summary())
# Out:
# Performing stepwise search to minimize aic
# Fit ARIMA(1,0,1)x(0,1,1,12) [intercept=True]; AIC=4368.367, BIC=4384.908, Time=1.293 seconds
# Fit ARIMA(0,0,0)x(0,1,0,12) [intercept=True]; AIC=4487.167, BIC=4493.783, Time=0.042 seconds
# Fit ARIMA(1,0,0)x(1,1,0,12) [intercept=True]; AIC=4393.354, BIC=4406.587, Time=0.742 seconds
# Fit ARIMA(0,0,1)x(0,1,1,12) [intercept=True]; AIC=4412.742, BIC=4425.975, Time=0.694 seconds
# Fit ARIMA(0,0,0)x(0,1,0,12) [intercept=False]; AIC=4519.815, BIC=4523.123, Time=0.027 seconds
# Fit ARIMA(1,0,1)x(0,1,0,12) [intercept=True]; AIC=4467.835, BIC=4481.068, Time=0.240 seconds
# Fit ARIMA(1,0,1)x(1,1,1,12) [intercept=True]; AIC=4369.713, BIC=4389.562, Time=1.200 seconds
# Fit ARIMA(1,0,1)x(0,1,2,12) [intercept=True]; AIC=4369.239, BIC=4389.089, Time=6.247 seconds
# Fit ARIMA(1,0,1)x(1,1,0,12) [intercept=True]; AIC=4390.422, BIC=4406.964, Time=0.908 seconds
# Fit ARIMA(1,0,1)x(1,1,2,12) [intercept=True]; AIC=4371.116, BIC=4394.274, Time=13.050 seconds
# Fit ARIMA(1,0,0)x(0,1,1,12) [intercept=True]; AIC=4375.946, BIC=4389.179, Time=0.658 seconds
# Fit ARIMA(2,0,1)x(0,1,1,12) [intercept=True]; AIC=4370.111, BIC=4389.961, Time=1.366 seconds
# Fit ARIMA(1,0,2)x(0,1,1,12) [intercept=True]; AIC=4370.768, BIC=4390.618, Time=1.296 seconds
# Fit ARIMA(0,0,0)x(0,1,1,12) [intercept=True]; AIC=4455.775, BIC=4465.700, Time=0.549 seconds
# Fit ARIMA(0,0,2)x(0,1,1,12) [intercept=True]; AIC=4397.185, BIC=4413.726, Time=0.913 seconds
# Fit ARIMA(2,0,0)x(0,1,1,12) [intercept=True]; AIC=4369.530, BIC=4386.071, Time=0.676 seconds
# Fit ARIMA(2,0,2)x(0,1,1,12) [intercept=True]; AIC=4371.682, BIC=4394.840, Time=2.052 seconds
# Total fit time: 31.978 seconds
#                                      SARIMAX Results
# ==========================================================================================
# Dep. Variable:                                  y   No. Observations:                  214
# Model:             SARIMAX(1, 0, 1)x(0, 1, 1, 12)   Log Likelihood               -2179.184
# Date:                            Thu, 06 Aug 2020   AIC                           4368.367
# Time:                                    21:56:43   BIC                           4384.908
# Sample:                                         0   HQIC                          4375.060
#                                             - 214
# Covariance Type:                              opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# intercept  -1466.1745    496.287     -2.954      0.003   -2438.878    -493.471
# ar.L1          0.6794      0.073      9.304      0.000       0.536       0.823
# ma.L1         -0.3123      0.139     -2.239      0.025      -0.586      -0.039
# ma.S.L12      -0.4235      0.039    -10.946      0.000      -0.499      -0.348
# sigma2      1.363e+08      0.004   3.38e+10      0.000    1.36e+08    1.36e+08
# ===================================================================================
# Ljung-Box (Q):                       65.58   Jarque-Bera (JB):                29.07
# Prob(Q):                              0.01   Prob(JB):                         0.00
# Heteroskedasticity (H):               0.44   Skew:                             0.19
# Prob(H) (two-sided):                  0.00   Kurtosis:                         4.82
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# [2] Covariance matrix is singular or near-singular, with condition number 4.49e+25. Standard errors may be unstable.

# %%
model_train_sarima.plot_diagnostics(figsize=(16,10))
plt.suptitle("X-Men SARIMA Diagnostics")
plt.savefig('X_Diag_SARIMA.png', dpi=300, bbox_inches='tight')
plt.show()

# %%
# Forecast
n_periods_sarima = 59
fc_sarima, confint_sarima = model_train_sarima.predict(n_periods=n_periods_sarima, return_conf_int=True)
index_of_fc_sarima = pd.date_range(train.index[-1], periods = n_periods_sarima, freq='MS')

# make series for plotting purpose
fc_series_sarima = pd.Series(fc_sarima, index=index_of_fc_sarima)
lower_series_sarima = pd.Series(confint_sarima[:, 0], index=index_of_fc_sarima)
upper_series_sarima = pd.Series(confint_sarima[:, 1], index=index_of_fc_sarima)

# Plot
plt.figure(figsize=(16,10))
plt.plot(test_no_movie, label='actual')
plt.plot(train_no_movie, label='training')
plt.plot(fc_series_sarima, label='forecast')
plt.fill_between(lower_series_sarima.index, lower_series_sarima, upper_series_sarima, color='k', alpha=.15)
plt.title("X-Men SARIMA Predicted vs Observed")
plt.legend(loc='upper left', fontsize=8)
plt.savefig('X_Predict_SARIMA.png', dpi=300, bbox_inches='tight')
plt.show()

# %%
mean_absolute_percentage_error(test_no_movie, fc_series_sarima)
# Out:
# 32.01987657447833

# %%
# With Movie_Playing External Predictor

# %%
#SARIMAX

# %%
#Auto SARIMAX Forecast to choose best p,d,q
model_train_sarimax = pm.auto_arima(train[['Units_Sold']], exogenous=train[['Movie_Playing']], start_p=1, start_q=1,
                      test='adf',       # use adftest to find optimal 'd'
                      max_p=3, max_q=3, # maximum p and q
                      m=12,              # frequency of series
                      d=None,           # let model determine 'd'
                      seasonal=True,   # No Seasonality
                      start_P=0, 
                      D=1, 
                      trace=True,
                      error_action='ignore',  
                      suppress_warnings=True,
                      stepwise=True)

print(model_train_sarimax.summary())
# Out:
# Performing stepwise search to minimize aic
# Fit ARIMA(1,0,1)x(0,1,1,12) [intercept=True]; AIC=4370.660, BIC=4390.509, Time=1.085 seconds
# Fit ARIMA(0,0,0)x(0,1,0,12) [intercept=True]; AIC=4485.416, BIC=4495.341, Time=0.069 seconds
# Fit ARIMA(1,0,0)x(1,1,0,12) [intercept=True]; AIC=4394.138, BIC=4410.680, Time=0.890 seconds
# Fit ARIMA(0,0,1)x(0,1,1,12) [intercept=True]; AIC=4411.404, BIC=4427.945, Time=0.814 seconds
# Fit ARIMA(0,0,0)x(0,1,0,12) [intercept=False]; AIC=5388.232, BIC=5394.849, Time=0.059 seconds
# Fit ARIMA(1,0,1)x(0,1,0,12) [intercept=True]; AIC=4466.725, BIC=4483.267, Time=0.293 seconds
# Fit ARIMA(1,0,1)x(1,1,1,12) [intercept=True]; AIC=4371.937, BIC=4395.095, Time=1.327 seconds
# Fit ARIMA(1,0,1)x(0,1,2,12) [intercept=True]; AIC=4371.381, BIC=4394.539, Time=7.746 seconds
# Fit ARIMA(1,0,1)x(1,1,0,12) [intercept=True]; AIC=4391.604, BIC=4411.454, Time=1.141 seconds
# Fit ARIMA(1,0,1)x(1,1,2,12) [intercept=True]; AIC=4373.226, BIC=4399.692, Time=12.689 seconds
# Fit ARIMA(1,0,0)x(0,1,1,12) [intercept=True]; AIC=4377.390, BIC=4393.932, Time=0.727 seconds
# Fit ARIMA(2,0,1)x(0,1,1,12) [intercept=True]; AIC=4372.339, BIC=4395.497, Time=1.798 seconds
# Fit ARIMA(1,0,2)x(0,1,1,12) [intercept=True]; AIC=4373.061, BIC=4396.219, Time=1.349 seconds
# Fit ARIMA(0,0,0)x(0,1,1,12) [intercept=True]; AIC=4453.710, BIC=4466.943, Time=0.659 seconds
# Fit ARIMA(0,0,2)x(0,1,1,12) [intercept=True]; AIC=4396.485, BIC=4416.334, Time=1.078 seconds
# Fit ARIMA(2,0,0)x(0,1,1,12) [intercept=True]; AIC=4371.591, BIC=4391.440, Time=0.745 seconds
# Fit ARIMA(2,0,2)x(0,1,1,12) [intercept=True]; AIC=4373.937, BIC=4400.403, Time=1.856 seconds
# Total fit time: 34.350 seconds
#                                      SARIMAX Results
# ==========================================================================================
# Dep. Variable:                                  y   No. Observations:                  214
# Model:             SARIMAX(1, 0, 1)x(0, 1, 1, 12)   Log Likelihood               -2179.330
# Date:                            Thu, 06 Aug 2020   AIC                           4370.660
# Time:                                    21:57:24   BIC                           4390.509
# Sample:                                04-30-1997   HQIC                          4378.691
#                                      - 01-31-2015
# Covariance Type:                              opg
# =================================================================================
#                     coef    std err          z      P>|z|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# intercept     -1513.0202    526.586     -2.873      0.004   -2545.109    -480.931
# Movie_Playing -4904.0644   3359.984     -1.460      0.144   -1.15e+04    1681.383
# ar.L1             0.6658      0.077      8.650      0.000       0.515       0.817
# ma.L1            -0.2998      0.144     -2.077      0.038      -0.583      -0.017
# ma.S.L12         -0.4111      0.039    -10.642      0.000      -0.487      -0.335
# sigma2         1.374e+08      0.004   3.71e+10      0.000    1.37e+08    1.37e+08
# ===================================================================================
# Ljung-Box (Q):                       58.92   Jarque-Bera (JB):                24.79
# Prob(Q):                              0.03   Prob(JB):                         0.00
# Heteroskedasticity (H):               0.47   Skew:                             0.13
# Prob(H) (two-sided):                  0.00   Kurtosis:                         4.69
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# [2] Covariance matrix is singular or near-singular, with condition number 5.06e+28. Standard errors may be unstable.

# %%
model_train_sarimax.plot_diagnostics(figsize=(16,10))
plt.suptitle("X-Men SARIMAX Diagnostics")
plt.savefig('X_Diag_SARIMAX.png', dpi=300, bbox_inches='tight')
plt.show()

# %%
# Forecast
n_periods_sarimax = 59
fc_sarimax, confint_sarimax = model_train_sarimax.predict(n_periods=n_periods_sarimax, exogenous=test[['Movie_Playing']], 
                                                          return_conf_int=True)
index_of_fc_sarimax = pd.date_range(train.index[-1], periods = n_periods_sarimax, freq='MS')

# make series for plotting purpose
fc_series_sarimax = pd.Series(fc_sarimax, index=index_of_fc_sarimax)
lower_series_sarimax = pd.Series(confint_sarimax[:, 0], index=index_of_fc_sarimax)
upper_series_sarimax = pd.Series(confint_sarimax[:, 1], index=index_of_fc_sarimax)

# Plot
plt.figure(figsize=(16,10))
plt.plot(test[['Units_Sold']], label='actual')
plt.plot(train[['Units_Sold']], label='training')
plt.plot(fc_series_sarimax, label='forecast')
plt.fill_between(lower_series_sarimax.index, lower_series_sarimax, upper_series_sarimax, color='k', alpha=.15)
plt.title("X-Men SARIMAX Predicted vs Observed")
plt.legend(loc='upper left', fontsize=8)
plt.savefig('X_Predict_SARIMAX.png', dpi=300, bbox_inches='tight')
plt.show()

# %%
mean_absolute_percentage_error(test_no_movie, fc_series_sarimax)
# Out:
# 31.426959827045465
